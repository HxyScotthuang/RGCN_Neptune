# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/partC/RGCN_Neptune/")

# %%
# %%capture
# !pip install torch_geometric
# !pip install torch_scatter
# !pip install torch_sparse

# %%
# %%capture
# !pip install neptune-client

# %%
# !python main.py --negative-sample 32  --dataset Hetionet --gpu 0  --n-bases 10
# Out:
# /usr/local/lib/python3.9/dist-packages/neptune/internal/backends/hosted_client.py:48: NeptuneDeprecationWarning: The 'neptune-client' package has been deprecated and will be removed in the future. Install the 'neptune' package instead. For more, see https://docs.neptune.ai/setup/upgrading/
#   from neptune.version import version as neptune_client_version
# /content/drive/MyDrive/Colab Notebooks/partC/RGCN_Neptune/main.py:9: NeptuneDeprecationWarning: You're importing the Neptune client library via the deprecated `neptune.new` module, which will be removed in a future release. Import directly from `neptune` instead.
#   import neptune.new as neptune
# https://app.neptune.ai/R-NBFNet/CMPNN-Rebuttal/e/CMPNNREB-137
# Namespace(graph_batch_size=30000, graph_split_size=0.5, negative_sample=32, n_epochs=10000, evaluate_every=500, dataset='Hetionet', dropout=0.2, gpu=0, lr=0.01, n_bases=10, regularization=0, grad_norm=1.0)
# load data from ./data/Hetionet
# num_entity: 45158
# ...

# %%
# !python main.py --negative-sample 32  --dataset wn18rr --gpu 0 --n-bases 5
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   3% 99/3034 [00:04<02:29, 19.65it/s]
#   3% 101/3034 [00:05<02:30, 19.45it/s]
#   3% 103/3034 [00:05<02:31, 19.35it/s]
#   3% 105/3034 [00:05<02:32, 19.25it/s]
#   4% 107/3034 [00:05<02:30, 19.40it/s]
#   4% 110/3034 [00:05<02:30, 19.47it/s]
#   4% 112/3034 [00:05<02:30, 19.40it/s]
#   4% 114/3034 [00:05<02:30, 19.35it/s]
#   4% 116/3034 [00:05<02:29, 19.47it/s]
#   4% 119/3034 [00:05<02:25, 20.01it/s]
#   4% 121/3034 [00:06<02:25, 19.97it/s]
#   4% 124/3034 [00:06<02:26, 19.84it/s]
#   4% 126/3034 [00:06<02:26, 19.88it/s]
#   4% 128/3034 [00:06<02:26, 19.84it/s]
#   4% 130/3034 [00:06<02:29, 19.41it/s]
#   4% 132/3034 [00:06<02:31, 19.14it/s]
#   4% 134/3034 [00:06<02:33, 18.84it/s]
#   4% 136/3034 [00:06<02:35, 18.60it/s]
#   5% 138/3034 [00:06<02:38, 18.30it/s]
#   5% 140/3034 [00:07<02:37, 18.37it/s]
#   5% 142/3034 [00:07<02:36, 18.43it/s]
#   5% 144/3034 [00:07<02:40, 17.97it/s]
#   5% 146/3034 [00:07<02:40, 17.96it/s]
# ...

# %%
# !python main.py --negative-sample 32 --dataset FB15k-237 --gpu 0 --n-bases 30
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#